# %% [markdown]
# Connect to the GDrive

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# load dataset
url = 'https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/epidemic/cases_age.csv'
import pandas as pd
data= pd.read_csv('https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/epidemic/cases_age.csv')
data
# Out:
#     week           state  abs_0_4  ...  capita_60_69  capita_70_79  capita_80_+
# 0    w24        Malaysia     2789  ...        132.34         98.32        86.10
# 1    w23        Malaysia     4609  ...        167.42        117.09       113.54
# 2    w22        Malaysia     5492  ...        216.90        159.57       137.21
# 3    w21        Malaysia     6682  ...        248.41        182.35       171.20
# 4    w20        Malaysia     7203  ...        283.58        211.30       204.93
# ..   ...             ...      ...  ...           ...           ...          ...
# 445   w4  W.P. Putrajaya       44  ...        255.32        142.86         0.00
# 446   w3  W.P. Putrajaya       21  ...        148.94        285.71      1000.00
# 447   w2  W.P. Putrajaya       19  ...        170.21        571.43         0.00
# 448   w1  W.P. Putrajaya       15  ...        148.94          0.00         0.00
# 449   w0  W.P. Putrajaya       14  ...        170.21        142.86         0.00
#
# ...

# %% [markdown]
# review the first 20 rows of your data using the head() function on the Pandas DataFrame.

# %%
data.head(20)
# Out:
#    week     state  abs_0_4  ...  capita_60_69  capita_70_79  capita_80_+
# 0   w24  Malaysia     2789  ...        132.34         98.32        86.10
# 1   w23  Malaysia     4609  ...        167.42        117.09       113.54
# 2   w22  Malaysia     5492  ...        216.90        159.57       137.21
# 3   w21  Malaysia     6682  ...        248.41        182.35       171.20
# 4   w20  Malaysia     7203  ...        283.58        211.30       204.93
# 5   w19  Malaysia     7708  ...        307.56        241.27       248.24
# 6   w18  Malaysia     8325  ...        322.51        276.38       273.16
# 7   w17  Malaysia     8556  ...        348.42        298.51       295.07
# 8   w16  Malaysia     8060  ...        352.04        309.71       311.18
# 9   w15  Malaysia     8108  ...        359.20        321.57       316.97
# 10  w14  Malaysia     7323  ...        324.16        298.88       297.08
# 11  w13  Malaysia     6304  ...        290.78        271.62       272.66
# ...

# %%
data.shape
# Out:
# (450, 32)

# %%
data.dtypes
# Out:
# week             object
# state            object
# abs_0_4           int64
# abs_5_11          int64
# abs_12_17         int64
# abs_18_29         int64
# abs_30_39         int64
# abs_40_49         int64
# abs_50_59         int64
# abs_60_69         int64
# abs_70_79         int64
# abs_80_+          int64
# perc_0_4        float64
# perc_5_11       float64
# perc_12_17      float64
# perc_18_29      float64
# perc_30_39      float64
# perc_40_49      float64
# perc_50_59      float64
# perc_60_69      float64
# perc_70_79      float64
# perc_80_+       float64
# capita_0_4      float64
# capita_5_11     float64
# capita_12_17    float64
# capita_18_29    float64
# capita_30_39    float64
# capita_40_49    float64
# capita_50_59    float64
# capita_60_69    float64
# capita_70_79    float64
# capita_80_+     float64
# dtype: object

# %%
data.describe()
# Out:
#            abs_0_4      abs_5_11  ...  capita_70_79  capita_80_+
# count   450.000000    450.000000  ...    450.000000   450.000000
# mean    596.040000    886.682222  ...    182.287822   175.642800
# std    1239.629867   1848.536614  ...    146.523302   170.032675
# min       0.000000      0.000000  ...      0.000000     0.000000
# 25%      90.000000    118.750000  ...     83.415000    63.967500
# 50%     224.000000    329.000000  ...    133.130000   111.145000
# 75%     530.250000    809.250000  ...    256.677500   245.710000
# max    8556.000000  13172.000000  ...    812.500000  1000.000000
#
# [8 rows x 30 columns]

# %%
data.corr(method='pearson')
# Out:
#                abs_0_4  abs_5_11  ...  capita_70_79  capita_80_+
# abs_0_4       1.000000  0.998349  ...      0.229453     0.243975
# abs_5_11      0.998349  1.000000  ...      0.227097     0.238871
# abs_12_17     0.984497  0.985351  ...      0.259576     0.264761
# abs_18_29     0.982204  0.977003  ...      0.233352     0.254395
# abs_30_39     0.984581  0.978613  ...      0.234964     0.262393
# abs_40_49     0.987570  0.983017  ...      0.242074     0.266652
# abs_50_59     0.994536  0.991713  ...      0.248283     0.263337
# abs_60_69     0.988723  0.988785  ...      0.249874     0.258554
# abs_70_79     0.969563  0.972051  ...      0.254981     0.257379
# abs_80_+      0.961905  0.964572  ...      0.259291     0.276931
# perc_0_4     -0.111348 -0.107978  ...     -0.029565    -0.097073
# perc_5_11    -0.100722 -0.085041  ...      0.006962    -0.105770
# perc_12_17    0.132485  0.142062  ...      0.241867     0.178210
# ...

# %%
data.skew()
# Out:
# abs_0_4         4.306094
# abs_5_11        4.431291
# abs_12_17       4.861842
# abs_18_29       4.381940
# abs_30_39       4.098277
# abs_40_49       4.198017
# abs_50_59       4.145248
# abs_60_69       4.077851
# abs_70_79       4.223982
# abs_80_+        4.285128
# perc_0_4        1.359772
# perc_5_11       0.536683
# perc_12_17      0.184652
# perc_18_29      0.759978
# perc_30_39      0.589592
# perc_40_49      0.382310
# perc_50_59      0.072517
# perc_60_69      1.313826
# perc_70_79      1.725314
# perc_80_+       1.990166
# capita_0_4      1.352402
# capita_5_11     1.222278
# capita_12_17    1.293311
# capita_18_29    1.672486
# capita_30_39    1.394796
# capita_40_49    1.336982
# capita_50_59    1.546653
# capita_60_69    1.531792
# capita_70_79    1.468794
# capita_80_+     1.779439
# dtype: float64

# %%
print('This distribution has skew')
print(data.skew())
print('This distribution has kurtosis')
print(data.kurt())
# Out:
# This distribution has skew
# abs_0_4         4.306094
# abs_5_11        4.431291
# abs_12_17       4.861842
# abs_18_29       4.381940
# abs_30_39       4.098277
# abs_40_49       4.198017
# abs_50_59       4.145248
# abs_60_69       4.077851
# abs_70_79       4.223982
# abs_80_+        4.285128
# perc_0_4        1.359772
# perc_5_11       0.536683
# perc_12_17      0.184652
# perc_18_29      0.759978
# perc_30_39      0.589592
# perc_40_49      0.382310
# perc_50_59      0.072517
# perc_60_69      1.313826
# perc_70_79      1.725314
# perc_80_+       1.990166
# capita_0_4      1.352402
# capita_5_11     1.222278
# capita_12_17    1.293311
# capita_18_29    1.672486
# capita_30_39    1.394796
# capita_40_49    1.336982
# capita_50_59    1.546653
# capita_60_69    1.531792
# capita_70_79    1.468794
# capita_80_+     1.779439
# dtype: float64
# This distribution has kurtosis
# abs_0_4         20.593759
# abs_5_11        22.024394
# abs_12_17       26.218439
# ...

# %%
data.isnull().sum()
data.isna().sum()
# Out:
# week            0
# state           0
# abs_0_4         0
# abs_5_11        0
# abs_12_17       0
# abs_18_29       0
# abs_30_39       0
# abs_40_49       0
# abs_50_59       0
# abs_60_69       0
# abs_70_79       0
# abs_80_+        0
# perc_0_4        0
# perc_5_11       0
# perc_12_17      0
# perc_18_29      0
# perc_30_39      0
# perc_40_49      0
# perc_50_59      0
# perc_60_69      0
# perc_70_79      0
# perc_80_+       0
# capita_0_4      0
# capita_5_11     0
# capita_12_17    0
# capita_18_29    0
# capita_30_39    0
# capita_40_49    0
# capita_50_59    0
# capita_60_69    0
# capita_70_79    0
# capita_80_+     0
# dtype: int64

# %%
data['state'].describe()
# Out:
# count          450
# unique          18
# top       Malaysia
# freq            25
# Name: state, dtype: object

# %% [markdown]
# Understand there is 18 unique state, to find out the category, we use value_counts() function

# %%
data['state'].value_counts()
# Out:
# Malaysia             25
# Pahang               25
# Johor                25
# W.P. Putrajaya       25
# Perlis               25
# W.P. Labuan          25
# Pulau Pinang         25
# Sarawak              25
# Klang Valley         25
# Perak                25
# Sabah                25
# W.P. Kuala Lumpur    25
# Kedah                25
# Selangor             25
# Kelantan             25
# Terengganu           25
# Negeri Sembilan      25
# Melaka               25
# Name: state, dtype: int64

# %% [markdown]
# Displaying the counts in ascending order

# %%
data['state'].value_counts(ascending=True)
# Out:
# Melaka               25
# Negeri Sembilan      25
# Terengganu           25
# Kelantan             25
# Selangor             25
# Kedah                25
# W.P. Kuala Lumpur    25
# Sabah                25
# Perak                25
# Klang Valley         25
# Sarawak              25
# Pulau Pinang         25
# W.P. Labuan          25
# Perlis               25
# W.P. Putrajaya       25
# Johor                25
# Pahang               25
# Malaysia             25
# Name: state, dtype: int64

# %%
data['state'].mean(ascending=True)

# %%
data['abs_50_59'].describe()
# Out:
# count      450.000000
# mean       894.055556
# std       1866.374260
# min          0.000000
# 25%        137.000000
# 50%        301.000000
# 75%        737.500000
# max      12551.000000
# Name: abs_50_59, dtype: float64

# %%
data['perc_50_59'].describe()
# Out:
# count    450.000000
# mean       8.952711
# std        2.235359
# min        0.000000
# 25%        7.980000
# 50%        8.815000
# 75%       10.007500
# max       21.800000
# Name: perc_50_59, dtype: float64

# %%
import matplotlib.pyplot as plt
data['state'].value_counts().plot(kind='bar',color='blue')
plt.xlabel('state')
plt.ylabel('cases')
plt.show()

# %% [markdown]
# investigate which age group has the highest incidence of covid 19?

# %%
data.groupby('state').abs_50_59.min()
# Out:
# state
# Johor                 245
# Kedah                 162
# Kelantan               83
# Klang Valley          552
# Malaysia             2250
# Melaka                 65
# Negeri Sembilan        66
# Pahang                118
# Perak                 105
# Perlis                  1
# Pulau Pinang          113
# Sabah                 123
# Sarawak                23
# Selangor              457
# Terengganu             34
# W.P. Kuala Lumpur      89
# W.P. Labuan             0
# W.P. Putrajaya          4
# Name: abs_50_59, dtype: int64

# %%
data.groupby('state').abs_50_59.max()
# Out:
# state
# Johor                 1034
# Kedah                 1221
# Kelantan               841
# Klang Valley          5529
# Malaysia             12551
# Melaka                 340
# Negeri Sembilan        729
# Pahang                 394
# Perak                  746
# Perlis                  52
# Pulau Pinang          1123
# Sabah                 1648
# Sarawak               2795
# Selangor              4058
# Terengganu             415
# W.P. Kuala Lumpur     1446
# W.P. Labuan             44
# W.P. Putrajaya          34
# Name: abs_50_59, dtype: int64

# %%
data.groupby('state').abs_50_59.agg(['min', 'max', 'count', 'median', 'mean'])
# Out:
#                     min    max  count  median     mean
# state
# Johor               245   1034     25     420   556.68
# Kedah               162   1221     25     299   503.92
# Kelantan             83    841     25     489   511.36
# Klang Valley        552   5529     25    1217  2199.56
# Malaysia           2250  12551     25    5809  6946.72
# Melaka               65    340     25     150   177.40
# Negeri Sembilan      66    729     25     124   214.24
# Pahang              118    394     25     258   263.04
# Perak               105    746     25     303   386.00
# Perlis                1     52     25      25    24.56
# Pulau Pinang        113   1123     25     260   447.04
# Sabah               123   1648     25     412   592.20
# Sarawak              23   2795     25     405   824.04
# Selangor            457   4058     25     942  1715.80
# Terengganu           34    415     25     239   240.48
# W.P. Kuala Lumpur    89   1446     25     244   470.92
# ...

# %% [markdown]
# From the statistical descriptive above, Klang Valley is found to be the highest for age 50-59 in epidemic registration?  need discussion.
# Points to discuss-every age category we need to do analysis for just taking the max value?

# %%
data.groupby('state').abs_50_59.agg(
 abs_50_59_min=('min'),
 abs_50_59_max=('max'),
)
# Out:
#                    abs_50_59_min  abs_50_59_max
# state
# Johor                        245           1034
# Kedah                        162           1221
# Kelantan                      83            841
# Klang Valley                 552           5529
# Malaysia                    2250          12551
# Melaka                        65            340
# Negeri Sembilan               66            729
# Pahang                       118            394
# Perak                        105            746
# Perlis                         1             52
# Pulau Pinang                 113           1123
# Sabah                        123           1648
# Sarawak                       23           2795
# Selangor                     457           4058
# Terengganu                    34            415
# W.P. Kuala Lumpur             89           1446
# W.P. Labuan                    0             44
# W.P. Putrajaya                 4             34

# %%
# load dataset Malaysia cases
url = 'https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/epidemic/cases_malaysia.csv'
import pandas as pd
Msia_case = pd.read_csv('https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/epidemic/cases_malaysia.csv')
Msia_case
# Out:
#            date  cases_new  ...  cluster_detentionCentre  cluster_workplace
# 0    2020-01-25          4  ...                      NaN                NaN
# 1    2020-01-26          0  ...                      NaN                NaN
# 2    2020-01-27          0  ...                      NaN                NaN
# 3    2020-01-28          0  ...                      NaN                NaN
# 4    2020-01-29          3  ...                      NaN                NaN
# ..          ...        ...  ...                      ...                ...
# 701  2021-12-26       2778  ...                      0.0               50.0
# 702  2021-12-27       2757  ...                      0.0               55.0
# 703  2021-12-28       2897  ...                      0.0               18.0
# 704  2021-12-29       3683  ...                      0.0               86.0
# 705  2021-12-30       3997  ...                      0.0               62.0
#
# [706 rows x 31 columns]

# %% [markdown]
# what are the objectives? For discussion in which month, in certain date, we have such active case, new case, cases recovered and so on?

# %%
Msia_case.groupby('date').cases_new.agg(['min', 'max', 'count', 'median', 'mean'])
# Out:
#              min   max  count  median  mean
# date
# 2020-01-25     4     4      1       4     4
# 2020-01-26     0     0      1       0     0
# 2020-01-27     0     0      1       0     0
# 2020-01-28     0     0      1       0     0
# 2020-01-29     3     3      1       3     3
# ...          ...   ...    ...     ...   ...
# 2021-12-23  3510  3510      1    3510  3510
# 2021-12-24  3528  3528      1    3528  3528
# 2021-12-25  3160  3160      1    3160  3160
# 2021-12-26  2778  2778      1    2778  2778
# 2021-12-27  2757  2757      1    2757  2757
#
# [703 rows x 5 columns]

# %%
Msia_case.groupby('date').cases_new.agg(
 cases_new_min=('min'),
 cases_new_max=('max'),
)
# Out:
#             cases_new_min  cases_new_max
# date
# 2020-01-25              4              4
# 2020-01-26              0              0
# 2020-01-27              0              0
# 2020-01-28              0              0
# 2020-01-29              3              3
# ...                   ...            ...
# 2021-12-26           2778           2778
# 2021-12-27           2757           2757
# 2021-12-28           2897           2897
# 2021-12-29           3683           3683
# 2021-12-30           3997           3997
#
# [706 rows x 2 columns]

# %%
# find the maximum covid 19 new case in the dataset
maxNewCase = max(Msia_case.cases_new)
print(maxNewCase)
# Out:
# 24599

# %%
maxdatecovid = max(Msia_case.groupby('date').cases_new)
maxdatecovid
# Out:
# ('2021-12-30', 705    3997
#  Name: cases_new, dtype: int64)

# %%
data.describe()
# Out:
#           cases_new  cases_import  ...  cluster_detentionCentre  cluster_workplace
# count    703.000000    703.000000  ...               361.000000         361.000000
# mean    3903.180654     10.186344  ...                61.036011         632.074792
# std     5561.099070     14.288071  ...                76.861357         497.789857
# min        0.000000      0.000000  ...                 0.000000          14.000000
# 25%       51.500000      3.000000  ...                 2.000000         181.000000
# 50%     1482.000000      6.000000  ...                37.000000         505.000000
# 75%     5353.500000     13.000000  ...                87.000000        1055.000000
# max    24599.000000    156.000000  ...               439.000000        2338.000000
#
# [8 rows x 30 columns]

# %%
# From the data above, we found that the recovered covid-19 cases are comparable to new covid cases. The unvaccinated cases are higher than 
# partially vaccinated and fully vaccinated cases. The lowest reported covid-19 cases are booster cases.
# As for population, the highest reported covid-19 cases fall in category of adult cases, followed by children cases. 
# The lowest number of population reported with covid-19 cases is adolescent.
# The highest age group reported with covid-19 cases is 18-29, followed by age group of 30-39.
# The lowest age group that reported with covid-19 cases is 80 and above, followed by age group of 70-79.
# The highest cluster reported with covid-19 cases is found to be "cluster workplace" followed by "cluster community".
# The lowest cluster on the other hand is shown to be "cluster import".

# %%
# load dataset
url = 'https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/epidemic/cases_state.csv'
import pandas as pd
state_case = pd.read_csv('https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/epidemic/cases_state.csv')
state_case
# Out:
#              date              state  ...  cases_70_79  cases_80
# 0      2020-01-25              Johor  ...            0         0
# 1      2020-01-25              Kedah  ...            0         0
# 2      2020-01-25           Kelantan  ...            0         0
# 3      2020-01-25             Melaka  ...            0         0
# 4      2020-01-25    Negeri Sembilan  ...            0         0
# ...           ...                ...  ...          ...       ...
# 11387  2022-01-05           Selangor  ...           28         6
# 11388  2022-01-05         Terengganu  ...            7         6
# 11389  2022-01-05  W.P. Kuala Lumpur  ...            2         2
# 11390  2022-01-05        W.P. Labuan  ...            1         0
# 11391  2022-01-05     W.P. Putrajaya  ...            0         0
#
# [11392 rows x 25 columns]

# %%
# what are the dates of this dataset is included?
state_case.date
# From 25-01-2020 to 30-12-2021
# Out:
# 0        2020-01-25
# 1        2020-01-25
# 2        2020-01-25
# 3        2020-01-25
# 4        2020-01-25
#             ...
# 11291    2021-12-30
# 11292    2021-12-30
# 11293    2021-12-30
# 11294    2021-12-30
# 11295    2021-12-30
# Name: date, Length: 11296, dtype: object

# %%
# How many states in the dataset?
# 16
# List the states involved

# %%
state_case['state'].value_counts()
# Out:
# Negeri Sembilan      706
# Melaka               706
# Kedah                706
# W.P. Kuala Lumpur    706
# Pulau Pinang         706
# Sarawak              706
# Sabah                706
# Kelantan             706
# Perlis               706
# Selangor             706
# W.P. Labuan          706
# W.P. Putrajaya       706
# Terengganu           706
# Perak                706
# Pahang               706
# Johor                706
# Name: state, dtype: int64

# %%
# To find max value of new cases of covid 19 in each state of Malaysia.
state_case.groupby('state').cases_new.agg('max')
# Out:
# state
# Johor                2785
# Kedah                2455
# Kelantan             1573
# Melaka               1120
# Negeri Sembilan      1619
# Pahang                926
# Perak                1596
# Perlis                200
# Pulau Pinang         2474
# Sabah                3487
# Sarawak              5291
# Selangor             8792
# Terengganu            993
# W.P. Kuala Lumpur    2880
# W.P. Labuan           253
# W.P. Putrajaya        122
# Name: cases_new, dtype: int64

# %%
# Plot a barplot to support the answer above
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
State = ['Putra', 'LB', 'KL', 'TRGN', 'Sel', 'SRW', 'SB', 'PNG', 'PL', 'Perak', 'PH', 'N9', 'MLK', 'KLT', 'KD','JH']
new_cases = [ 122,253,2880,993,8792,5291,3487,2474,200,1596,926,1619,1120,1573,2455,2785]
ax.bar(State,new_cases)
plt.show()

# %%
# From the barplot, we can conclude that the state of Selangor has the highest new cases of covid 19 in Malaysia.

# %%
# Compare covid cases between partially vaccination, fully vaccination and with booster in all the states in Malaysia

# %%
state_case.groupby('state').cases_pvax.agg('max')
# Out:
# state
# Johor                 958
# Kedah                 613
# Kelantan              376
# Melaka                676
# Negeri Sembilan       412
# Pahang                220
# Perak                 628
# Perlis                 31
# Pulau Pinang          766
# Sabah                1085
# Sarawak               291
# Selangor             3890
# Terengganu            352
# W.P. Kuala Lumpur    1094
# W.P. Labuan            39
# W.P. Putrajaya         39
# Name: cases_pvax, dtype: int64

# %%
state_case.groupby('state').cases_fvax.agg('max')
# Out:
# state
# Johor                 671
# Kedah                 460
# Kelantan              613
# Melaka                256
# Negeri Sembilan       213
# Pahang                344
# Perak                 536
# Perlis                134
# Pulau Pinang          651
# Sabah                 872
# Sarawak              3610
# Selangor             1596
# Terengganu            385
# W.P. Kuala Lumpur     443
# W.P. Labuan            24
# W.P. Putrajaya         62
# Name: cases_fvax, dtype: int64

# %%
state_case.groupby('state').cases_boost.agg('max')
# Out:
# state
# Johor                21
# Kedah                37
# Kelantan             33
# Melaka               23
# Negeri Sembilan      15
# Pahang               26
# Perak                27
# Perlis                2
# Pulau Pinang         19
# Sabah                22
# Sarawak              34
# Selangor             64
# Terengganu           18
# W.P. Kuala Lumpur    27
# W.P. Labuan           3
# W.P. Putrajaya        5
# Name: cases_boost, dtype: int64

# %%
# Plot another barplot to compare among cases that are partially vaccinated (pvac), fully vaccinated and complete dose with booster in all states.
import numpy as np
import matplotlib.pyplot as plt
 
# set width of bar
barWidth = 0.25
fig = plt.subplots(figsize =(12, 8))
 
# set height of bar
PVAX = [39, 39, 1094, 352, 3890, 291, 1085, 766, 31, 628, 220, 412, 676, 376, 613, 958]
FVAX = [62, 24, 443, 385, 1596, 3610, 872, 651, 134, 536, 344, 213, 256, 613, 460, 671]
BOOSTER = [5, 3, 27, 18, 64, 34, 22, 19, 2, 27, 26, 15, 23, 33, 37, 21]
 
# Set position of bar on X axis
br1 = np.arange(len(PVAX))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
 
# Make the plot
plt.bar(br1, PVAX, color ='r', width = barWidth,
        edgecolor ='grey', label ='PVAX')
plt.bar(br2, FVAX, color ='g', width = barWidth,
        edgecolor ='grey', label ='FVAX')
plt.bar(br3, BOOSTER, color ='b', width = barWidth,
        edgecolor ='grey', label ='BOOSTER')
 
# Adding Xticks
plt.xlabel('State', fontweight ='bold', fontsize = 15)
plt.ylabel('new cases', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(PVAX))],
        ['Putra', 'LB', 'KL', 'TRGN', 'Sel', 'SRW', 'SB', 'PNG', 'PL', 'Perak', 'PH', 'N9', 'MLK', 'KLT', 'KD','JH'])
 
plt.legend()
plt.show()

# %%
# From the above barplot, we can conclude that:
# In the state of Kuala Lumpur, Selangor, Sabah, Penang, Perak, Negeri Sembilan, Melaka, Kedah, Johor
# partially vaccinated cases are more than fully vaccinated cases.
# In the state of Terengganu, Sarawak, Perlis, Pahang and Kelantan are found to have higher fully vaccinated cases than 
# partially vaccinated cases.
# Putrajaya and Labuan showed small differences in reported new covid cases of partial and fully vaccination.
# Overall after a booster dose, study demonstrates that the least covid new cases have been reported or detected.

# %%
# Plot a boxplot to compare the covid child cases, adolescent case, adult case and elderly case.

# %%
state_case['cases_child'].describe()
# Out:
# count    11296.000000
# mean        32.657489
# std         80.787098
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%         28.000000
# max       1002.000000
# Name: cases_child, dtype: float64

# %%
state_case['cases_adolescent'].describe()
# Out:
# count    11296.000000
# mean        16.089147
# std         41.957838
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%         12.000000
# max        527.000000
# Name: cases_adolescent, dtype: float64

# %%
state_case['cases_adult'].describe()
# Out:
# count    11296.000000
# mean       166.730701
# std        425.068336
# min          0.000000
# 25%          0.000000
# 50%         13.000000
# 75%        160.000000
# max       6549.000000
# Name: cases_adult, dtype: float64

# %%
state_case['cases_elderly'].describe()
# Out:
# count    11296.000000
# mean        21.791519
# std         49.012566
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%         22.000000
# max        637.000000
# Name: cases_elderly, dtype: float64

# %%
import matplotlib.pyplot as plt
state = state_case.state
active = state_case.cases_active
plt.plot(state,active)
plt.title('the new cases of the states')
plt.xlabel('states')
plt.ylabel('active cases')
plt.show()

# %% [markdown]
# As shown above, the active covid 19 cases among the states are the same.

# %%
# Plot a boxplot to compare the covid child cases, adolescent case, adult case and elderly case.
# The notch = True attribute creates the notch format to the box plot
# patch_artist = True fills the boxplot with colors, different colors for different boxes.
# The vert = 0 attribute creates horizontal box plot. 
# Import libraries
import matplotlib.pyplot as plt
import numpy as np
 
# Creating dataset
np.random.seed(10)
data_child = np.random.normal(81, 33, 800)
data_adolescent = np.random.normal(41 ,16, 800)
data_adult = np.random.normal(425, 167, 800)
data_elderly = np.random.normal(49, 22, 800)
data = [data_child, data_adolescent, data_adult, data_elderly]
 
fig = plt.figure(figsize =(8, 6))
ax = fig.add_subplot(111)
 
# Creating axes instance
Population = ax.boxplot(data, patch_artist = True,
                notch ='True', vert = 0)
 
colors = ['#0000FF', '#00FF00',
          '#FFFF00', '#FF00FF']
 
for patch, color in zip(Population['boxes'], colors):
    patch.set_facecolor(color)
 
# changing color and linewidth of
# whiskers
for whisker in Population['whiskers']:
    whisker.set(color ='#8B008B',
                linewidth = 1.5,
                linestyle =":")
 
# changing color and linewidth of
# caps
for cap in Population['caps']:
    cap.set(color ='#8B008B',
            linewidth = 2)
 
# changing color and linewidth of
# medians
for median in Population['medians']:
    median.set(color ='red',
               linewidth = 3)
 
# changing style of fliers
for flier in Population['fliers']:
    flier.set(marker ='D',
              color ='#e7298a',
              alpha = 0.5)
     
# x-axis labels
ax.set_yticklabels(['data_child', 'data_adolescent',
                    'data_adult', 'data_elderly'])
 
# Adding title
plt.title("Covid cases between child, adolescent, adult and elderly")
 
# Removing top axes and right axes
# ticks
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()
     
# show plot
plt.show(Population)

# %%
#Plot multiple line chart to compare the partially-vaccinated cases, fully-vaccinated cases and boosted cases in Selangor.
Selangor_case = state_case.query('state=="Selangor"')
Selangor_partial = Selangor_case.cases_pvax
Selangor_full = Selangor_case.cases_fvax
Selangor_boost = Selangor_case.cases_boost
# importing package
import matplotlib.pyplot as plt
import numpy as np
  

  
# plot lines
plt.plot(Selangor_partial, label = "partial")
plt.plot(Selangor_full, label = "full")
plt.plot(Selangor_boost, label = "boost")

plt.legend()
plt.show()

# %%
# from the above line chart above, we can conclude that most of the cases fall in "partially-vaccinated" in Selangor.

# %%
# plot another line chart to compare the Covid 19 child cases, adolescent cases, adult cases and elderly cases in Selangor.

# %%
import pandas as pd
state_case = pd.read_csv('https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/epidemic/cases_state.csv')
state_case
# Out:
#              date              state  ...  cases_70_79  cases_80
# 0      2020-01-25              Johor  ...            0         0
# 1      2020-01-25              Kedah  ...            0         0
# 2      2020-01-25           Kelantan  ...            0         0
# 3      2020-01-25             Melaka  ...            0         0
# 4      2020-01-25    Negeri Sembilan  ...            0         0
# ...           ...                ...  ...          ...       ...
# 11387  2022-01-05           Selangor  ...           28         6
# 11388  2022-01-05         Terengganu  ...            7         6
# 11389  2022-01-05  W.P. Kuala Lumpur  ...            2         2
# 11390  2022-01-05        W.P. Labuan  ...            1         0
# 11391  2022-01-05     W.P. Putrajaya  ...            0         0
#
# [11392 rows x 25 columns]

# %% [markdown]
# objective: To find the state that has the highest new cases, cases import,active cases in certain month? or currently which state has the highest cases who is partially vaccinated or fully vaccinated or even with booster?

# %%
# load dataset
url = 'https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/epidemic/clusters.csv'
import pandas as pd
cluster = pd.read_csv('https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/epidemic/clusters.csv')
cluster
# Out:
#                                        cluster  ...                                         summary_en
# 0                          KLUSTER WARGA JEPUN  ...                                                NaN
# 1                                  KLUSTER UDA  ...                                                NaN
# 2     KLUSTER KEAGAMAAN (TABLIGH SRI PETALING)  ...                                                NaN
# 3                    KLUSTER TABLIGH NEW DELHI  ...                                                NaN
# 4                                KLUSTER AIROD  ...                                                NaN
# ...                                        ...  ...                                                ...
# 6105            KLUSTER INDUSTRI DUTAMAS EMPAT  ...  This cluster identification resulted from targ...
# 6106                       KLUSTER KUALA BIKAM  ...  The index case for this cluster is a 37 years ...
# ...

# %%
# load dataset
url = 'https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/epidemic/deaths_age.csv'
import pandas as pd
deaths_age= pd.read_csv('https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/epidemic/deaths_age.csv')
deaths_age
# Out:
#     week           state  abs_0_4  ...  capita_60_69  capita_70_79  capita_80_+
# 0    w24        Malaysia        2  ...         13.76         16.62        24.42
# 1    w23        Malaysia        2  ...         16.88         22.13        33.23
# 2    w22        Malaysia        2  ...         23.52         25.68        39.78
# 3    w21        Malaysia        1  ...         21.69         29.69        50.35
# 4    w20        Malaysia        2  ...         21.28         28.76        51.11
# ..   ...             ...      ...  ...           ...           ...          ...
# 427   w5  W.P. Putrajaya        0  ...          0.00          0.00         0.00
# 428   w4  W.P. Putrajaya        0  ...          0.00          0.00         0.00
# 429   w3  W.P. Putrajaya        0  ...          0.00          0.00         0.00
# 430   w2  W.P. Putrajaya        0  ...          0.00          0.00         0.00
# 431   w1  W.P. Putrajaya        0  ...         21.28          0.00         0.00
#
# ...

# %% [markdown]
# objective: To investigate the age group that has the highest death of Covid 19?

# %%
# load dataset
url = 'https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/epidemic/hospital.csv'
import pandas as pd
data= pd.read_csv('https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/epidemic/hospital.csv')
data
# Out:
#             date              state  beds  ...  hosp_covid  hosp_pui  hosp_noncovid
# 0     2020-03-24              Johor  1440  ...          18         9              1
# 1     2020-03-24              Kedah  1218  ...          46         5             12
# 2     2020-03-24           Kelantan  1463  ...          78        58             23
# 3     2020-03-24             Melaka  1091  ...          19        10             12
# 4     2020-03-24    Negeri Sembilan  1223  ...          90        13              8
# ...          ...                ...   ...  ...         ...       ...            ...
# 9886  2021-12-27           Selangor  5338  ...         422       333           2747
# 9887  2021-12-27         Terengganu  1587  ...         209         6            932
# 9888  2021-12-27  W.P. Kuala Lumpur  3963  ...         195        22           1490
# 9889  2021-12-27        W.P. Labuan   202  ...           4         0             70
# ...

# %% [markdown]
# Objective - To investigate the highest icu bed occupancy in each state in certain month?

# %% [markdown]
# **Cases and Testing**
# **cases_malaysia**.csv: Daily recorded COVID-19 cases at country level, as of 1200 of date.
# **cases_state**.csv: Daily recorded COVID-19 cases at state level, as of 1200 of date.
# **clusters**.csv: Exhaustive list of announced clusters with relevant epidemiological datapoints, as of 2359 of date of update.
# **tests_malaysia**.csv: Daily tests (note: not necessarily unique individuals) by type at country level, as of 2359 of date.
# **tests_state**.csv: Daily tests (note: not necessarily unique individuals) by type at state level, as of 2359 of date.
# Healthcare
# **pkrc**.csv: Flow of patients to/out of Covid-19 Quarantine and Treatment Centres (PKRC), with capacity and utilisation as of 2359 of date.
# hospital.csv: Flow of patients to/out of hospitals, with capacity and utilisation as of 2359 of date.
# **icu**.csv: Capacity and utilisation of intensive care unit (ICU) beds as of 2359 of date.
# Deaths
# **deaths_malaysia**.csv: Daily deaths due to COVID-19 at country level, as of 1200 of date.
# **deaths_state**.csv: Daily deaths due to COVID-19 at state level, as of 1200 of date.
# **Vaccination**
# MoH collaborates with MoSTI and the COVID-19 Immunisation Task Force (CITF) to publish open data on Malaysia's vaccination rollout. All relevant data can be found at this repo.
#
# ***Mobility and Contact Tracing***
# checkin_malaysia.csv: Daily checkins on MySejahtera at country level, as of 2359 of date.
# checkin_state.csv: Daily checkins on MySejahtera at state level, as of 2359 of date.
# checkin_malaysia_time.csv: Time distribution of daily checkins on MySejahtera at country level, as of 2359 of date.
# trace_malaysia.csv: Daily casual contacts traced and hotspots identified by HIDE, at country level, as of 2359 of date.

# %%
# load dataset
url = 'https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/epidemic/tests_malaysia.csv'
import pandas as pd
data= pd.read_csv('https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/epidemic/tests_malaysia.csv')
data
# Out:
#            date  rtk-ag    pcr
# 0    2020-01-24       0      2
# 1    2020-01-25       0      5
# 2    2020-01-26       0     14
# 3    2020-01-27       0     24
# 4    2020-01-28       0     53
# ..          ...     ...    ...
# 697  2021-12-21  100683  38066
# 698  2021-12-22   97297  34113
# 699  2021-12-23   87440  29044
# 700  2021-12-24   70747  29315
# 701  2021-12-25   56395  27003
#
# [702 rows x 3 columns]
